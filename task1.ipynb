# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

np.random.seed(0)
X = np.random.rand(100, 1)
Y = 5.5 * X + 3.1 + np.random.rand(100, 1)
plt.scatter(X,Y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

#Gradient Descent Method
a_current = 0
b_current = 0

learning_rate = 0.1

n = float(len(X))

for i in range(1000): 
    Y_predicted = a_current*X + b_current
    a_gradient = (-2/n) * sum(X * (Y - Y_predicted))
    b_gradient = (-2/n) * sum(Y - Y_predicted)
    a_current = a_current - learning_rate * a_gradient
    b_current = b_current - learning_rate * b_gradient
    
print (f'Predicted a value - {a_current}\nPredicted b value - {b_current}')


Y_predicted = a*X + b

plt.scatter(X, Y) 
plt.plot([min(X), max(X)], [min(Y_predicted), max(Y_predicted)], color='red')
plt.show()
# Out:
# Predicted a value - [5.43654716]
# Predicted b value - [3.658082]
